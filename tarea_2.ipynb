# %% [markdown]
# # **Tarea Nº 2**

# %% [markdown]
# Curso:          Fundamentos de Programación en Python para Macroeconomía y Finanzas
# Profesor:       Victor Fuentes Campos

# %% [markdown]
# - Fecha y hora de entrega: Sábado 6 de enero, 11:59pm
# - Agregue los nombres de las personas con las que discutió esta tarea: ____ Jorge and Joshua ______
# - Envíe su tarea haciendo el `push` de su código a su repo en GitHub Classroom:

# %% [markdown]
# ## Filtering rows

# %% [markdown]
# 1. Import the `flights.csv` dataset. Find all flights that:
#
#     a. Had an arrival delay of three or more hours
#     b. Flew to Houston (IAH or HOU)
#     c. Were operated by United, American, or Southwest
#     d. Departed in spring (March, April, and June)
#     e. Arrived more than two hours late, but didn’t leave late
#     f. Were delayed by at least an hour, but made up over 30 minutes in flight 7. Departed between midnight and 5am (inclusive)

# %%
import pandas as pd

# %%
# Solution
flights = pd.read_csv("flights.csv", index_col=0)

# %%
#A
display(flights.loc[(flights['arr_delay']>=3)].head(10))
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1   2013      1    1     517.0             515        2.0     830.0
# 2   2013      1    1     533.0             529        4.0     850.0
# 3   2013      1    1     542.0             540        2.0     923.0
# 6   2013      1    1     554.0             558       -4.0     740.0
# 7   2013      1    1     555.0             600       -5.0     913.0
# 10  2013      1    1     558.0             600       -2.0     753.0
# 13  2013      1    1     558.0             600       -2.0     924.0
# 15  2013      1    1     559.0             600       -1.0     941.0
# 19  2013      1    1     600.0             600        0.0     837.0
# 22  2013      1    1     602.0             605       -3.0     821.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 1              819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 2              830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 3              850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 6              728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 7              854       19.0      B6     507  N516JB    EWR  FLL     158.0
# 10             745        8.0      AA     301  N3ALAA    LGA  ORD     138.0
# 13             917        7.0      UA     194  N29129    JFK  LAX     345.0
# 15             910       31.0      AA     707  N3DUAA    LGA  DFW     257.0
# 19             825       12.0      MQ    4650  N542MQ    LGA  ATL     134.0
# 22             805       16.0      MQ    4401  N730MQ    LGA  DTW     105.0
#
#     distance  hour  minute            time_hour
# 1       1400     5      15  2013-01-01 05:00:00
# 2       1416     5      29  2013-01-01 05:00:00
# 3       1089     5      40  2013-01-01 05:00:00
# 6        719     5      58  2013-01-01 05:00:00
# 7       1065     6       0  2013-01-01 06:00:00
# 10       733     6       0  2013-01-01 06:00:00
# 13      2475     6       0  2013-01-01 06:00:00
# 15      1389     6       0  2013-01-01 06:00:00
# 19       762     6       0  2013-01-01 06:00:00
# 22       502     6       5  2013-01-01 06:00:00

# %%
# B
display(flights.loc[((flights['dest']=='IAH') | (flights['dest']=='HOU'))].head(10))
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1    2013      1    1     517.0             515        2.0     830.0
# 2    2013      1    1     533.0             529        4.0     850.0
# 33   2013      1    1     623.0             627       -4.0     933.0
# 82   2013      1    1     728.0             732       -4.0    1041.0
# 90   2013      1    1     739.0             739        0.0    1104.0
# 178  2013      1    1     908.0             908        0.0    1228.0
# 237  2013      1    1    1028.0            1026        2.0    1350.0
# 248  2013      1    1    1044.0            1045       -1.0    1352.0
# 269  2013      1    1    1114.0             900      134.0    1447.0
# 312  2013      1    1    1205.0            1200        5.0    1503.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 1               819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 2               830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 33              932        1.0      UA     496  N459UA    LGA  IAH     229.0
# 82             1038        3.0      UA     473  N488UA    LGA  IAH     238.0
# 90             1038       26.0      UA    1479  N37408    EWR  IAH     249.0
# 178            1219        9.0      UA    1220  N12216    EWR  IAH     233.0
# 237            1339       11.0      UA    1004  N76508    LGA  IAH     237.0
# 248            1351        1.0      UA     455  N667UA    EWR  IAH     229.0
# 269            1222      145.0      UA    1086  N76502    LGA  IAH     248.0
# 312            1505       -2.0      UA    1461  N39418    EWR  IAH     221.0
#
#      distance  hour  minute            time_hour
# 1        1400     5      15  2013-01-01 05:00:00
# 2        1416     5      29  2013-01-01 05:00:00
# 33       1416     6      27  2013-01-01 06:00:00
# 82       1416     7      32  2013-01-01 07:00:00
# 90       1400     7      39  2013-01-01 07:00:00
# 178      1400     9       8  2013-01-01 09:00:00
# 237      1416    10      26  2013-01-01 10:00:00
# 248      1400    10      45  2013-01-01 10:00:00
# 269      1416     9       0  2013-01-01 09:00:00
# 312      1400    12       0  2013-01-01 12:00:00

# %%
# C : Se interpreto que la coma despues de united era un error de tipeo y usamos la columna carrier y usamos united america(UA) y united southwest(US)
display((flights.loc[(flights['carrier']=='UA') | (flights['carrier']=='US')]).head(10))
# Out:
#     year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1   2013      1    1     517.0             515        2.0     830.0
# 2   2013      1    1     533.0             529        4.0     850.0
# 6   2013      1    1     554.0             558       -4.0     740.0
# 13  2013      1    1     558.0             600       -2.0     924.0
# 14  2013      1    1     558.0             600       -2.0     923.0
# 17  2013      1    1     559.0             600       -1.0     854.0
# 25  2013      1    1     607.0             607        0.0     858.0
# 27  2013      1    1     611.0             600       11.0     945.0
# 31  2013      1    1     622.0             630       -8.0    1017.0
# 33  2013      1    1     623.0             627       -4.0     933.0
#
#     sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 1              819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 2              830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 6              728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 13             917        7.0      UA     194  N29129    JFK  LAX     345.0
# 14             937      -14.0      UA    1124  N53441    EWR  SFO     361.0
# 17             902       -8.0      UA    1187  N76515    EWR  LAS     337.0
# 25             915      -17.0      UA    1077  N53442    EWR  MIA     157.0
# 27             931       14.0      UA     303  N532UA    JFK  SFO     366.0
# 31            1014        3.0      US     245  N807AW    EWR  PHX     342.0
# 33             932        1.0      UA     496  N459UA    LGA  IAH     229.0
#
#     distance  hour  minute            time_hour
# 1       1400     5      15  2013-01-01 05:00:00
# 2       1416     5      29  2013-01-01 05:00:00
# 6        719     5      58  2013-01-01 05:00:00
# 13      2475     6       0  2013-01-01 06:00:00
# 14      2565     6       0  2013-01-01 06:00:00
# 17      2227     6       0  2013-01-01 06:00:00
# 25      1085     6       7  2013-01-01 06:00:00
# 27      2586     6       0  2013-01-01 06:00:00
# 31      2133     6      30  2013-01-01 06:00:00
# 33      1416     6      27  2013-01-01 06:00:00

# %%
#D
display((flights.loc[((flights['month']==3) | (flights['month']==4) | (flights['month']==6))]).head(10))
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 136248  2013      3    1       4.0            2159      125.0     318.0
# 136249  2013      3    1      50.0            2358       52.0     526.0
# 136250  2013      3    1     117.0            2245      152.0     223.0
# 136251  2013      3    1     454.0             500       -6.0     633.0
# 136252  2013      3    1     505.0             515      -10.0     746.0
# 136253  2013      3    1     521.0             530       -9.0     813.0
# 136254  2013      3    1     537.0             540       -3.0     856.0
# 136255  2013      3    1     541.0             545       -4.0    1014.0
# 136256  2013      3    1     549.0             600      -11.0     639.0
# 136257  2013      3    1     550.0             600      -10.0     747.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 136248              56      142.0      B6      11  N706JB    JFK  FLL
# 136249             438       48.0      B6     707  N794JB    JFK  SJU
# 136250            2354      149.0      B6     608  N328JB    JFK  PWM
# 136251             648      -15.0      US    1117  N177US    EWR  CLT
# 136252             810      -24.0      UA     475  N527UA    EWR  IAH
# 136253             827      -14.0      UA    1714  N76523    LGA  IAH
# 136254             850        6.0      AA    1141  N5EPAA    JFK  MIA
# 136255            1023       -9.0      B6     725  N653JB    JFK  BQN
# 136256             703      -24.0      US    2114  N749US    LGA  BOS
# 136257             801      -14.0      EV    4911  N760EV    EWR  DTW
#
#         air_time  distance  hour  minute            time_hour
# 136248     166.0      1069    21      59  2013-03-01 21:00:00
# 136249     198.0      1598    23      58  2013-03-01 23:00:00
# 136250      48.0       273    22      45  2013-03-01 22:00:00
# 136251      79.0       529     5       0  2013-03-01 05:00:00
# 136252     199.0      1400     5      15  2013-03-01 05:00:00
# 136253     213.0      1416     5      30  2013-03-01 05:00:00
# 136254     173.0      1089     5      40  2013-03-01 05:00:00
# 136255     191.0      1576     5      45  2013-03-01 05:00:00
# 136256      31.0       184     6       0  2013-03-01 06:00:00
# 136257      89.0       488     6       0  2013-03-01 06:00:00

# %%
# E
display(flights.loc[((flights['dep_delay']<=0) & (flights['arr_delay']>=120))])
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 22912   2013      1   27    1419.0            1420       -1.0    1754.0
# 33012   2013     10    7    1350.0            1350        0.0    1736.0
# 33020   2013     10    7    1357.0            1359       -2.0    1858.0
# 41076   2013     10   16     657.0             700       -3.0    1258.0
# 55986   2013     11    1     658.0             700       -2.0    1329.0
# 152767  2013      3   18    1844.0            1847       -3.0      39.0
# 180894  2013      4   17    1635.0            1640       -5.0    2049.0
# 181271  2013      4   18     558.0             600       -2.0    1149.0
# 181328  2013      4   18     655.0             700       -5.0    1213.0
# 213694  2013      5   22    1827.0            1830       -3.0    2217.0
# 214513  2013      5   23    1810.0            1810        0.0    2208.0
# 226435  2013      6    5    1604.0            1615      -11.0    2041.0
# 235034  2013      6   14    1708.0            1710       -2.0    2227.0
# 244330  2013      6   24    1602.0            1605       -3.0    2134.0
# 247569  2013      6   27    2052.0            2100       -8.0      13.0
# 249958  2013      6   30    1423.0            1425       -2.0    1816.0
# 250690  2013      7    1     905.0             905        0.0    1443.0
# 256341  2013      7    7    1659.0            1700       -1.0    2050.0
# 256359  2013      7    7    1727.0            1730       -3.0    2203.0
# 256374  2013      7    7    1746.0            1755       -9.0    2133.0
# 256406  2013      7    7    1823.0            1830       -7.0    2201.0
# 270743  2013      7   22    1555.0            1600       -5.0    2139.0
# 270753  2013      7   22    1606.0            1615       -9.0    2056.0
# 270763  2013      7   22    1628.0            1630       -2.0    2151.0
# 276565  2013      7   28    1710.0            1711       -1.0    2248.0
# 287149  2013      8    8    1457.0            1500       -3.0    1828.0
# 291440  2013      8   13     657.0             659       -2.0    1015.0
# 305986  2013      8   28    1157.0            1200       -3.0    1520.0
# 325765  2013      9   19     656.0             700       -4.0    1037.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 22912             1550      124.0      MQ    3728  N1EAMQ    EWR  ORD
# 33012             1526      130.0      EV    5181  N611QX    LGA  MSN
# 33020             1654      124.0      AA    1151  N3CMAA    LGA  DFW
# 41076             1056      122.0      B6       3  N703JB    JFK  SJU
# 55986             1015      194.0      VX     399  N629VA    JFK  LAX
# 152767            2219      140.0      UA     389  N560UA    JFK  SFO
# 180894            1845      124.0      MQ    4540  N721MQ    LGA  DTW
# 181271             850      179.0      AA     707  N3EXAA    LGA  DFW
# 181328             950      143.0      AA    2083  N565AA    EWR  DFW
# 213694            2010      127.0      MQ    4674  N518MQ    LGA  CLE
# 214513            2000      128.0      MQ    4626  N525MQ    LGA  CMH
# 226435            1840      121.0      MQ    4657  N510MQ    LGA  ATL
# 235034            2015      132.0      AA     181  N320AA    JFK  LAX
# 244330            1916      138.0      DL     706   N3768    JFK  AUS
# 247569            2210      123.0      US    2144  N952UW    LGA  BOS
# 249958            1554      142.0      B6    2402  N206JB    JFK  BUF
# 250690            1223      140.0      DL    1057  N337NB    LGA  MIA
# 256341            1823      147.0      US    2183  N948UW    LGA  DCA
# 256359            1951      132.0      F9     837  N263AV    LGA  DEN
# 256374            1921      132.0      B6    1407  N374JB    JFK  IAD
# 256406            1955      126.0      MQ    3486  N724MQ    LGA  BNA
# 270743            1938      121.0      DL     141  N713TW    JFK  SFO
# 270753            1831      145.0      DL    1619  N970DL    LGA  MSP
# 270763            1939      132.0      B6     423  N625JB    JFK  LAX
# 276565            2039      129.0      B6     167  N510JB    JFK  OAK
# 287149            1624      124.0      US    2185  N746UW    LGA  DCA
# 291440             814      121.0      EV    4522  N14188    EWR  BNA
# 305986            1316      124.0      US    2179  N737US    LGA  DCA
# 325765             833      124.0      UA     331  N808UA    LGA  ORD
#
#         air_time  distance  hour  minute            time_hour
# 22912      135.0       719    14      20  2013-01-27 14:00:00
# 33012      117.0       812    13      50  2013-10-07 13:00:00
# 33020      192.0      1389    13      59  2013-10-07 13:00:00
# 41076      225.0      1598     7       0  2013-10-16 07:00:00
# 55986      336.0      2475     7       0  2013-11-01 07:00:00
# 152767     386.0      2586    18      47  2013-03-18 18:00:00
# 180894     130.0       502    16      40  2013-04-17 16:00:00
# 181271     234.0      1389     6       0  2013-04-18 06:00:00
# 181328     230.0      1372     7       0  2013-04-18 07:00:00
# 213694      90.0       419    18      30  2013-05-22 18:00:00
# 214513      82.0       479    18      10  2013-05-23 18:00:00
# 226435     158.0       762    16      15  2013-06-05 16:00:00
# 235034     334.0      2475    17      10  2013-06-14 17:00:00
# 244330     247.0      1521    16       5  2013-06-24 16:00:00
# 247569      46.0       184    21       0  2013-06-27 21:00:00
# 249958      80.0       301    14      25  2013-06-30 14:00:00
# 250690     183.0      1096     9       5  2013-07-01 09:00:00
# 256341      64.0       214    17       0  2013-07-07 17:00:00
# 256359     236.0      1620    17      30  2013-07-07 17:00:00
# 256374      78.0       228    17      55  2013-07-07 17:00:00
# 256406     113.0       764    18      30  2013-07-07 18:00:00
# 270743     371.0      2586    16       0  2013-07-22 16:00:00
# 270753     140.0      1020    16      15  2013-07-22 16:00:00
# 270763     332.0      2475    16      30  2013-07-22 16:00:00
# 276565     353.0      2576    17      11  2013-07-28 17:00:00
# 287149      70.0       214    15       0  2013-08-08 15:00:00
# 291440     146.0       748     6      59  2013-08-13 06:00:00
# 305986      63.0       214    12       0  2013-08-28 12:00:00
# 325765     192.0       733     7       0  2013-09-19 07:00:00

# %%
flights.describe()
# Out:
#            year          month            day       dep_time  sched_dep_time  \
# count  336776.0  336776.000000  336776.000000  328521.000000   336776.000000
# mean     2013.0       6.548510      15.710787    1349.109947     1344.254840
# std         0.0       3.414457       8.768607     488.281791      467.335756
# min      2013.0       1.000000       1.000000       1.000000      106.000000
# 25%      2013.0       4.000000       8.000000     907.000000      906.000000
# 50%      2013.0       7.000000      16.000000    1401.000000     1359.000000
# 75%      2013.0      10.000000      23.000000    1744.000000     1729.000000
# max      2013.0      12.000000      31.000000    2400.000000     2359.000000
#
#            dep_delay       arr_time  sched_arr_time      arr_delay  \
# count  328521.000000  328063.000000   336776.000000  327346.000000
# mean       12.639070    1502.054999     1536.380220       6.895377
# std        40.210061     533.264132      497.457142      44.633292
# min       -43.000000       1.000000        1.000000     -86.000000
# 25%        -5.000000    1104.000000     1124.000000     -17.000000
# 50%        -2.000000    1535.000000     1556.000000      -5.000000
# 75%        11.000000    1940.000000     1945.000000      14.000000
# max      1301.000000    2400.000000     2359.000000    1272.000000
#
#               flight       air_time       distance           hour  \
# count  336776.000000  327346.000000  336776.000000  336776.000000
# mean     1971.923620     150.686460    1039.912604      13.180247
# std      1632.471938      93.688305     733.233033       4.661316
# min         1.000000      20.000000      17.000000       1.000000
# 25%       553.000000      82.000000     502.000000       9.000000
# 50%      1496.000000     129.000000     872.000000      13.000000
# 75%      3465.000000     192.000000    1389.000000      17.000000
# max      8500.000000     695.000000    4983.000000      23.000000
#
#               minute
# count  336776.000000
# mean       26.230100
# std        19.300846
# min         0.000000
# 25%         8.000000
# 50%        29.000000
# 75%        44.000000
# max        59.000000

# %%
# F
display((flights.loc[(flights['dep_delay']>=60) & (flights['arr_delay']<=30)]).head(10))
# Out:
#        year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 2523   2013      1    3    1850.0            1745       65.0    2148.0
# 2578   2013      1    3    1950.0            1845       65.0    2228.0
# 2604   2013      1    3    2015.0            1915       60.0    2135.0
# 4552   2013      1    6    1019.0             900       79.0    1558.0
# 5730   2013      1    7    1543.0            1430       73.0    1758.0
# 9135   2013      1   11    1020.0             920       60.0    1311.0
# 10286  2013      1   12    1706.0            1600       66.0    1949.0
# 10397  2013      1   12    1953.0            1845       68.0    2154.0
# 16261  2013      1   19    1456.0            1355       61.0    1636.0
# 17845  2013      1   21    1531.0            1430       61.0    1843.0
#
#        sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 2523             2120       28.0      AA     177  N332AA    JFK  SFO
# 2578             2227        1.0      B6      91  N636JB    JFK  OAK
# 2604             2111       24.0      9E    3525  N903XJ    JFK  ORD
# 4552             1530       28.0      HA      51  N385HA    JFK  HNL
# 5730             1735       23.0      AA     883  N4XBAA    EWR  DFW
# 9135             1245       26.0      AA     721  N434AA    LGA  DFW
# 10286            1927       22.0      DL    2139  N982DL    LGA  MIA
# 10397            2137       17.0      9E    3369  N919XJ    JFK  MSY
# 16261            1615       21.0      EV    5469  N724EV    LGA  MEM
# 17845            1815       28.0      DL    2126  N710TW    JFK  SFO
#
#        air_time  distance  hour  minute            time_hour
# 2523      314.0      2586    17      45  2013-01-03 17:00:00
# 2578      319.0      2576    18      45  2013-01-03 18:00:00
# 2604      110.0       740    19      15  2013-01-03 19:00:00
# 4552      611.0      4983     9       0  2013-01-06 09:00:00
# 5730      177.0      1372    14      30  2013-01-07 14:00:00
# 9135      201.0      1389     9      20  2013-01-11 09:00:00
# 10286     141.0      1096    16       0  2013-01-12 16:00:00
# 10397     165.0      1182    18      45  2013-01-12 18:00:00
# 16261     137.0       963    13      55  2013-01-19 13:00:00
# 17845     345.0      2586    14      30  2013-01-21 14:00:00

# %%
# 7
display((flights.loc[(flights['hour']>=0) & (flights['hour']<=5)]).head(10))
# Out:
#      year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1    2013      1    1     517.0             515        2.0     830.0
# 2    2013      1    1     533.0             529        4.0     850.0
# 3    2013      1    1     542.0             540        2.0     923.0
# 4    2013      1    1     544.0             545       -1.0    1004.0
# 6    2013      1    1     554.0             558       -4.0     740.0
# 16   2013      1    1     559.0             559        0.0     702.0
# 845  2013      1    2     458.0             500       -2.0     703.0
# 846  2013      1    2     512.0             515       -3.0     809.0
# 847  2013      1    2     535.0             540       -5.0     831.0
# 848  2013      1    2     536.0             529        7.0     840.0
#
#      sched_arr_time  arr_delay carrier  flight tailnum origin dest  air_time  \
# 1               819       11.0      UA    1545  N14228    EWR  IAH     227.0
# 2               830       20.0      UA    1714  N24211    LGA  IAH     227.0
# 3               850       33.0      AA    1141  N619AA    JFK  MIA     160.0
# 4              1022      -18.0      B6     725  N804JB    JFK  BQN     183.0
# 6               728       12.0      UA    1696  N39463    EWR  ORD     150.0
# 16              706       -4.0      B6    1806  N708JB    JFK  BOS      44.0
# 845             650       13.0      US    1030  N162UW    EWR  CLT     108.0
# 846             819      -10.0      UA    1453  N76515    EWR  IAH     214.0
# 847             850      -19.0      AA    1141  N621AA    JFK  MIA     156.0
# 848             828       12.0      UA     407  N493UA    LGA  IAH     231.0
#
#      distance  hour  minute            time_hour
# 1        1400     5      15  2013-01-01 05:00:00
# 2        1416     5      29  2013-01-01 05:00:00
# 3        1089     5      40  2013-01-01 05:00:00
# 4        1576     5      45  2013-01-01 05:00:00
# 6         719     5      58  2013-01-01 05:00:00
# 16        187     5      59  2013-01-01 05:00:00
# 845       529     5       0  2013-01-02 05:00:00
# 846      1400     5      15  2013-01-02 05:00:00
# 847      1089     5      40  2013-01-02 05:00:00
# 848      1416     5      29  2013-01-02 05:00:00

# %% [markdown]
# 2. How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %%
# Solution

flights.isnull().sum()
## while missing values might indicate incomplete records or data collections issues
## It's possible that cancelled or delayed flights might have taken part on the missing values issue
# Out:
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64

# %% [markdown]
# 3. What happens to observations **with missing values in `arr_time`** when you filter by **`arr_time == 1800`**? Why? (Hint: compare `2000 == 1800`, `1800 == 1800`, and `NA == 1800`).

# %%
# Solution
flights['arr_time'].describe()
# Out:
# count    328063.000000
# mean       1502.054999
# std         533.264132
# min           1.000000
# 25%        1104.000000
# 50%        1535.000000
# 75%        1940.000000
# max        2400.000000
# Name: arr_time, dtype: float64

# %%
flights.loc[flights['arr_time']==1800].isna().sum() # cuando igualo con 1800 todos los valores que no sean 1800 se van incluidos los nan
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         1
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          1
# distance          0
# hour              0
# minute            0
# time_hour         0
# dtype: int64

# %%
flights.loc[flights['arr_time']==2000].isna().sum() # Sucede lo mismo en este caso los nan para esa columna se van
# Out:
# year              0
# month             0
# day               0
# dep_time          0
# sched_dep_time    0
# dep_delay         0
# arr_time          0
# sched_arr_time    0
# arr_delay         3
# carrier           0
# flight            0
# tailnum           0
# origin            0
# dest              0
# air_time          3
# distance          0
# hour              0
# minute            0
# time_hour         0
# dtype: int64

# %% [markdown]
# 4. What does `False & None` evaluate to? Why?

# %%
# Solution
flights.loc[flights['arr_time']==False] # Equal False evaluate if the value is False, and for int values display no values
# Out:
# Empty DataFrame
# Columns: [year, month, day, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, carrier, flight, tailnum, origin, dest, air_time, distance, hour, minute, time_hour]
# Index: []

# %%
flights.loc[flights['arr_time']==None] # Equal None evaluate if the values are empty
# Out:
# Empty DataFrame
# Columns: [year, month, day, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, carrier, flight, tailnum, origin, dest, air_time, distance, hour, minute, time_hour]
# Index: []

# %%
flights.loc[(flights['arr_time']==(False & None))] # error but we can use 'and'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 flights.loc[(flights['arr_time']==(False & None))] # error but we can use 'and'
#
# TypeError: unsupported operand type(s) for &: 'bool' and 'NoneType'

# %%
flights.loc[(flights['arr_time']==(False and None))]
# Out:
# Empty DataFrame
# Columns: [year, month, day, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, carrier, flight, tailnum, origin, dest, air_time, distance, hour, minute, time_hour]
# Index: []

# %% [markdown]
# ## Select columns

# %% [markdown]
# 5. Brainstorm as many distinct ways as possible to select `dep_time`, `dep_delay`, `arr_time`, and `arr_delay` from `flights`.

# %%
# Solution
flights.loc[(flights['arr_time']>= flights['dep_time'] )]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1       2013      1    1     517.0             515        2.0     830.0
# 2       2013      1    1     533.0             529        4.0     850.0
# 3       2013      1    1     542.0             540        2.0     923.0
# 4       2013      1    1     544.0             545       -1.0    1004.0
# 5       2013      1    1     554.0             600       -6.0     812.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2237.0            2245       -8.0    2345.0
# 336766  2013      9   30    2240.0            2245       -5.0    2334.0
# 336767  2013      9   30    2240.0            2250      -10.0    2347.0
# 336768  2013      9   30    2241.0            2246       -5.0    2345.0
# 336769  2013      9   30    2307.0            2255       12.0    2359.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 1                  819       11.0      UA    1545  N14228    EWR  IAH
# 2                  830       20.0      UA    1714  N24211    LGA  IAH
# 3                  850       33.0      AA    1141  N619AA    JFK  MIA
# 4                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 5                  837      -25.0      DL     461  N668DN    LGA  ATL
# ...                ...        ...     ...     ...     ...    ...  ...
# 336765            2353       -8.0      B6     234  N318JB    JFK  BTV
# 336766            2351      -17.0      B6    1816  N354JB    JFK  SYR
# 336767               7      -20.0      B6    2002  N281JB    JFK  BUF
# 336768               1      -16.0      B6     486  N346JB    JFK  ROC
# 336769            2358        1.0      B6     718  N565JB    JFK  BOS
#
#         air_time  distance  hour  minute            time_hour
# 1          227.0      1400     5      15  2013-01-01 05:00:00
# 2          227.0      1416     5      29  2013-01-01 05:00:00
# 3          160.0      1089     5      40  2013-01-01 05:00:00
# 4          183.0      1576     5      45  2013-01-01 05:00:00
# 5          116.0       762     6       0  2013-01-01 06:00:00
# ...          ...       ...   ...     ...                  ...
# 336765      43.0       266    22      45  2013-09-30 22:00:00
# 336766      41.0       209    22      45  2013-09-30 22:00:00
# 336767      52.0       301    22      50  2013-09-30 22:00:00
# 336768      47.0       264    22      46  2013-09-30 22:00:00
# 336769      33.0       187    22      55  2013-09-30 22:00:00
#
# [317430 rows x 19 columns]

# %%
# Salio antes y llego antes
flights.loc[((flights['dep_delay']<=0) & (flights['arr_delay']<=0))]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 4       2013      1    1     544.0             545       -1.0    1004.0
# 5       2013      1    1     554.0             600       -6.0     812.0
# 8       2013      1    1     557.0             600       -3.0     709.0
# 9       2013      1    1     557.0             600       -3.0     838.0
# 11      2013      1    1     558.0             600       -2.0     849.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336765  2013      9   30    2237.0            2245       -8.0    2345.0
# 336766  2013      9   30    2240.0            2245       -5.0    2334.0
# 336767  2013      9   30    2240.0            2250      -10.0    2347.0
# 336768  2013      9   30    2241.0            2246       -5.0    2345.0
# 336770  2013      9   30    2349.0            2359      -10.0     325.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 4                 1022      -18.0      B6     725  N804JB    JFK  BQN
# 5                  837      -25.0      DL     461  N668DN    LGA  ATL
# 8                  723      -14.0      EV    5708  N829AS    LGA  IAD
# 9                  846       -8.0      B6      79  N593JB    JFK  MCO
# 11                 851       -2.0      B6      49  N793JB    JFK  PBI
# ...                ...        ...     ...     ...     ...    ...  ...
# 336765            2353       -8.0      B6     234  N318JB    JFK  BTV
# 336766            2351      -17.0      B6    1816  N354JB    JFK  SYR
# 336767               7      -20.0      B6    2002  N281JB    JFK  BUF
# 336768               1      -16.0      B6     486  N346JB    JFK  ROC
# 336770             350      -25.0      B6     745  N516JB    JFK  PSE
#
#         air_time  distance  hour  minute            time_hour
# 4          183.0      1576     5      45  2013-01-01 05:00:00
# 5          116.0       762     6       0  2013-01-01 06:00:00
# 8           53.0       229     6       0  2013-01-01 06:00:00
# 9          140.0       944     6       0  2013-01-01 06:00:00
# 11         149.0      1028     6       0  2013-01-01 06:00:00
# ...          ...       ...   ...     ...                  ...
# 336765      43.0       266    22      45  2013-09-30 22:00:00
# 336766      41.0       209    22      45  2013-09-30 22:00:00
# 336767      52.0       301    22      50  2013-09-30 22:00:00
# 336768      47.0       264    22      46  2013-09-30 22:00:00
# 336770     196.0      1617    23      59  2013-09-30 23:00:00
#
# [158900 rows x 19 columns]

# %%
# Salio tarde, llego antes
flights.loc[((flights['dep_delay']>0) & (flights['arr_delay']<=0))]
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 20      2013      1    1     601.0             600        1.0     844.0
# 48      2013      1    1     644.0             636        8.0     931.0
# 50      2013      1    1     646.0             645        1.0     910.0
# 51      2013      1    1     646.0             645        1.0    1023.0
# 69      2013      1    1     701.0             700        1.0    1123.0
# ...      ...    ...  ...       ...             ...        ...       ...
# 336715  2013      9   30    2035.0            2029        6.0    2318.0
# 336719  2013      9   30    2050.0            2045        5.0      20.0
# 336741  2013      9   30    2115.0            2110        5.0    2246.0
# 336745  2013      9   30    2121.0            2100       21.0    2349.0
# 336750  2013      9   30    2129.0            2059       30.0    2230.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 20                 850       -6.0      B6     343  N644JB    EWR  PBI
# 48                 940       -9.0      UA    1701  N75435    EWR  FLL
# 50                 916       -6.0      UA     883  N569UA    LGA  DEN
# 51                1030       -7.0      UA    1496  N38727    EWR  SNA
# 69                1154      -31.0      UA    1203  N77296    EWR  SJU
# ...                ...        ...     ...     ...     ...    ...  ...
# 336715            2337      -19.0      UA    1039  N78524    EWR  AUS
# 336719              53      -33.0      DL     347  N396DA    JFK  SJU
# 336741            2255       -9.0      MQ    3603  N519MQ    LGA  DTW
# 336745              14      -25.0      DL    2363  N193DN    JFK  LAX
# 336750            2232       -2.0      EV    5048  N751EV    LGA  RIC
#
#         air_time  distance  hour  minute            time_hour
# 20         147.0      1023     6       0  2013-01-01 06:00:00
# 48         151.0      1065     6      36  2013-01-01 06:00:00
# 50         243.0      1620     6      45  2013-01-01 06:00:00
# 51         380.0      2434     6      45  2013-01-01 06:00:00
# 69         188.0      1608     7       0  2013-01-01 07:00:00
# ...          ...       ...   ...     ...                  ...
# 336715     191.0      1504    20      29  2013-09-30 20:00:00
# 336719     188.0      1598    20      45  2013-09-30 20:00:00
# 336741      72.0       502    21      10  2013-09-30 21:00:00
# 336745     296.0      2475    21       0  2013-09-30 21:00:00
# 336750      45.0       292    20      59  2013-09-30 20:00:00
#
# [35442 rows x 19 columns]

# %% [markdown]
# ## Sort columns

# %% [markdown]
# 6. Sort flights to find the most delayed flights by arrival time. Hint: End your code with head(1) to only print that row.

# %%
# Solution
flights.sort_values(by='arr_time', ascending=False).head(1)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 244604  2013      6   24    2246.0            1859      227.0    2400.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 244604            2026      214.0      EV    4131  N11150    EWR  RIC
#
#         air_time  distance  hour  minute            time_hour
# 244604      48.0       277    18      59  2013-06-24 18:00:00

# %% [markdown]
# 7. Find the top 5 flights that left earliest relative to their scheduled departure. Only show the tail number, date and number of minutes early they departed at.

# %%
# Solution

# %%
(flights.loc[(flights['dep_time']<=flights['sched_dep_time']) & (flights['dep_delay']<0), ['tailnum', 'time_hour', 'dep_delay']].sort_values(by='dep_delay', ascending=True)).head(5)
# Out:
#        tailnum            time_hour  dep_delay
# 89674   N592JB  2013-12-07 21:00:00      -43.0
# 113634  N612DL  2013-02-03 20:00:00      -33.0
# 64502   N825AS  2013-11-10 14:00:00      -32.0
# 9620    N934DL  2013-01-11 19:00:00      -30.0
# 24916   N208FR  2013-01-29 17:00:00      -27.0

# %% [markdown]
# 8. How could you sort all missing values to the start?

# %%
# Solution
flights.sort_values(by='arr_time', na_position='first')
# Entendí que se refería a un valor, por lo que repetí el arr_time de la preg 6
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 755     2013      1    1    2016.0            1930       46.0       NaN
# 839     2013      1    1       NaN            1630        NaN       NaN
# 840     2013      1    1       NaN            1935        NaN       NaN
# 841     2013      1    1       NaN            1500        NaN       NaN
# 842     2013      1    1       NaN             600        NaN       NaN
# ...      ...    ...  ...       ...             ...        ...       ...
# 64888   2013     11   10    2027.0            2015       12.0    2400.0
# 120641  2013      2   11    2220.0            2000      140.0    2400.0
# 299005  2013      8   20    2302.0            2305       -3.0    2400.0
# 138872  2013      3    3    2248.0            2251       -3.0    2400.0
# 29919   2013     10    3    2210.0            2030      100.0    2400.0
#
#         sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 755               2220        NaN      EV    4204  N14168    EWR  OKC
# 839               1815        NaN      EV    4308  N18120    EWR  RDU
# 840               2240        NaN      AA     791  N3EHAA    LGA  DFW
# 841               1825        NaN      AA    1925  N3EVAA    LGA  MIA
# 842                901        NaN      B6     125  N618JB    JFK  FLL
# ...                ...        ...     ...     ...     ...    ...  ...
# 64888             2354        6.0      DL     427  N197DN    JFK  LAX
# 120641            2137      143.0      EV    4106  N13914    EWR  GSO
# 299005              13      -13.0      B6     718  N348JB    JFK  BOS
# 138872            2357        3.0      B6      22  N307JB    JFK  SYR
# 29919             2251       69.0      EV    5209  N709EV    LGA  CHS
#
#         air_time  distance  hour  minute            time_hour
# 755          NaN      1325    19      30  2013-01-01 19:00:00
# 839          NaN       416    16      30  2013-01-01 16:00:00
# 840          NaN      1389    19      35  2013-01-01 19:00:00
# 841          NaN      1096    15       0  2013-01-01 15:00:00
# 842          NaN      1069     6       0  2013-01-01 06:00:00
# ...          ...       ...   ...     ...                  ...
# 64888      329.0      2475    20      15  2013-11-10 20:00:00
# 120641      79.0       445    20       0  2013-02-11 20:00:00
# 299005      37.0       187    23       5  2013-08-20 23:00:00
# 138872      44.0       209    22      51  2013-03-03 22:00:00
# 29919       86.0       641    20      30  2013-10-03 20:00:00
#
# [336776 rows x 19 columns]

# %% [markdown]
# ## Add new variables

# %% [markdown]
# 9. Currently `dep_time` and `arr_time` are convenient to look at, but hard to compute with because they’re not really continuous numbers. Convert them to number of minutes since midnight in new vars called `arr_time_min` and `dep_time_min`

# %%
# Solution
flights['arr_time_min'] = flights['arr_time']*60
flights['arr_time_min'] = flights['arr_time_min'].mod(1440)

flights['dep_time_min'] = flights['dep_time']*60
flights['dep_time_min'] = flights['dep_time_min'].mod(1440)
flights.head()
# Out:
#    year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 1  2013      1    1     517.0             515        2.0     830.0
# 2  2013      1    1     533.0             529        4.0     850.0
# 3  2013      1    1     542.0             540        2.0     923.0
# 4  2013      1    1     544.0             545       -1.0    1004.0
# 5  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 1             819       11.0      UA  ...   N14228    EWR  IAH    227.0
# 2             830       20.0      UA  ...   N24211    LGA  IAH    227.0
# 3             850       33.0      AA  ...   N619AA    JFK  MIA    160.0
# 4            1022      -18.0      B6  ...   N804JB    JFK  BQN    183.0
# 5             837      -25.0      DL  ...   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour arr_time_min  dep_time_min
# 1      1400     5      15  2013-01-01 05:00:00        840.0         780.0
# 2      1416     5      29  2013-01-01 05:00:00        600.0         300.0
# 3      1089     5      40  2013-01-01 05:00:00        660.0         840.0
# 4      1576     5      45  2013-01-01 05:00:00       1200.0         960.0
# 5       762     6       0  2013-01-01 06:00:00       1200.0         120.0
#
# [5 rows x 21 columns]

# %% [markdown]
# 10. Make a plot to compare `air_time` with `arr_time_min` - `dep_time_min`

# %%
import matplotlib.pyplot as plt

# %%
fig, axes=plt.subplots(1,1, figsize=(10,6))
axes.scatter((flights['arr_time_min'] - flights['dep_time_min']), flights['air_time'])
axes.set_xlabel('Diferencia entre llegada y salida')
axes.set_ylabel('Tiempo de vuelo')
plt.show()

# %% [markdown]
# 11. We expect `air_time` and `arr_time_min` - `dep_time_min` to be the same, but they’re not. Why not?
# Identify a major data issue and subtle one.

# %%
# Solution

# %% [markdown]
# 12. Implement your fix to the major probelm. Remake the plot from the previous question.

# %%
# Solution

# %% [markdown]
# 13. Find the 10 most delayed flights

# %%
# Solution
flights.sort_values('arr_delay', ascending=True).head(10)
# Out:
#         year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 199669  2013      5    7    1715.0            1729      -14.0    1944.0
# 211125  2013      5   20     719.0             735      -16.0     951.0
# 198764  2013      5    6    1826.0            1830       -4.0    2045.0
# 195237  2013      5    2    1947.0            1949       -2.0    2209.0
# 196936  2013      5    4    1816.0            1820       -4.0    2017.0
# 195219  2013      5    2    1926.0            1929       -3.0    2157.0
# 204580  2013      5   13     657.0             700       -3.0     908.0
# 199883  2013      5    7    2054.0            2055       -1.0    2317.0
# 198729  2013      5    6    1753.0            1755       -2.0    2004.0
# 195402  2013      5    3     616.0             630      -14.0     803.0
#
#         sched_arr_time  arr_delay carrier  ...  tailnum origin dest air_time  \
# 199669            2110      -86.0      VX  ...   N843VA    EWR  SFO    315.0
# 211125            1110      -79.0      VX  ...   N840VA    JFK  SFO    316.0
# 198764            2200      -75.0      AA  ...   N3KCAA    JFK  SEA    289.0
# 195237            2324      -75.0      UA  ...   N851UA    EWR  LAX    300.0
# 196936            2131      -74.0      AS  ...   N551AS    EWR  SEA    281.0
# 195219            2310      -73.0      UA  ...   N24212    EWR  SFO    314.0
# 204580            1019      -71.0      B6  ...   N805JB    JFK  LAX    290.0
# 199883              28      -71.0      UA  ...   N806UA    EWR  SFO    309.0
# 198729            2115      -71.0      DL  ...   N3760C    JFK  PDX    283.0
# 195402             913      -70.0      US  ...   N507AY    JFK  PHX    266.0
#
#         distance  hour  minute            time_hour arr_time_min  dep_time_min
# 199669      2565    17      29  2013-05-07 17:00:00          0.0         660.0
# 211125      2586     7      35  2013-05-20 07:00:00        900.0        1380.0
# 198764      2422    18      30  2013-05-06 18:00:00        300.0         120.0
# 195237      2454    19      49  2013-05-02 19:00:00         60.0         180.0
# 196936      2402    18      20  2013-05-04 18:00:00         60.0         960.0
# 195219      2565    19      29  2013-05-02 19:00:00       1260.0         360.0
# 204580      2475     7       0  2013-05-13 07:00:00       1200.0         540.0
# 199883      2565    20      55  2013-05-07 20:00:00        780.0         840.0
# 198729      2454    17      55  2013-05-06 17:00:00        720.0          60.0
# 195402      2153     6      30  2013-05-03 06:00:00        660.0         960.0
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Summarizing grouped data

# %% [markdown]
# 14. Calculate average delays by destination for flights originating in NYC. Create a variable which ranks destinations from worst to best, where 1 is the worst rank.

# %%
# Solution
average_delay = flights['arr_delay'].mean()

# %%
std_df = flights['arr_delay'].std()

# %%
flights['rank'] = (flights['arr_delay']-flights['arr_delay'].min())/(flights['arr_delay'].max()-flights['arr_delay'].min())

# %%
flights['rank'].describe()
# Out:
# count    327346.000000
# mean          0.068406
# std           0.032867
# min           0.000000
# 25%           0.050810
# 50%           0.059647
# 75%           0.073638
# max           1.000000
# Name: rank, dtype: float64

# %% [markdown]
# 15. Which plane (`tailnum`) has the most minutes of delays total?

# %%
# Solution
flights.loc[flights['arr_delay'].max(), ['tailnum']]
# Out:
# tailnum    N630JB
# Name: 1272, dtype: object

# %% [markdown]
# 16. Which airlines only offer flights from New York to one other airport?

# %%
# Solution
flights.loc[(flights['origin'] != flights['dest']), 'carrier'].unique()
# Out:
# array(['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS',
#        '9E', 'F9', 'HA', 'YV', 'OO'], dtype=object)

# %% [markdown]
# 17. Calculate the median arrival delay by airline.

# %%
# Solution
flights.groupby('carrier')[['arr_delay']].median()
# Out:
#          arr_delay
# carrier
# 9E            -7.0
# AA            -9.0
# AS           -17.0
# B6            -3.0
# DL            -8.0
# EV            -1.0
# F9             6.0
# FL             5.0
# HA           -13.0
# MQ            -1.0
# OO            -7.0
# UA            -6.0
# US            -6.0
# VX            -9.0
# WN            -3.0
# YV            -2.0

# %% [markdown]
# 18. ExpressJet has a median arrival delay of -1 minutes while US Airways has a median arrival delay of -6 minutes. Does this tell you that US Airways is a more reliable airline? Why or why not?

# %%
# Solution

# Para saber si US Airways es mejor no basta con el arrival delay en la media, sino tambien es importante
# ver los tiempos de vuelo, por que de nada me sirve llegar antes si a priori los vuelos para una misma distancia son más lentos

# %% [markdown]
# 19. Median arrival delay may not be the best metric for our needs. Brainstorm at least 4 additional ways to assess the typical delay characteristics of a group of flights.

# %%
# Solution

# la variable que construi es buenap ara rankear a las aereolineas por su delay
flights['rank']
# Out:
# 1         0.071429
# 2         0.078056
# 3         0.087629
# 4         0.050074
# 5         0.044919
#             ...
# 336772         NaN
# 336773         NaN
# 336774         NaN
# 336775         NaN
# 336776         NaN
# Name: rank, Length: 336776, dtype: float64

# %% [markdown]
# 20. Write a code which calculates your delay measures separately by airline. Do particular airlines perform poorly on multiple metrics?

# %%
# Solution
# segun distintas metricas, la media de delay puede ser alta pero la mediana me indica que la mayoria de sus vuelos llegan antes de tiempo, por ejemplo en el caso de 9E, y esto es para la mayoria de los casos

flights.groupby('carrier')[['arr_delay']].agg(['mean', 'median'])
# Out:
#          arr_delay
#               mean median
# carrier
# 9E        7.379669   -7.0
# AA        0.364291   -9.0
# AS       -9.930889  -17.0
# B6        9.457973   -3.0
# DL        1.644341   -8.0
# EV       15.796431   -1.0
# F9       21.920705    6.0
# FL       20.115906    5.0
# HA       -6.915205  -13.0
# MQ       10.774733   -1.0
# OO       11.931034   -7.0
# UA        3.558011   -6.0
# US        2.129595   -6.0
# VX        1.764464   -9.0
# WN        9.649120   -3.0
# YV       15.556985   -2.0
